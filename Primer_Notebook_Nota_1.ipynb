# %% [markdown]
# <a href="https://colab.research.google.com/github/yerelynperez123-ai/Prog_Civil_2026_1/blob/main/Primer_Notebook_Nota_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Universidad de Sucre
#
# **Facultad de Ingenieria**
#
# **Departamento de Ingenieria Civil**
#
# **Yerelyn Zucell Perez Forez: 1100335261**

# %% [markdown]
# # **Fundamentos de Programación para Ingeniería**.
#
# ---
#
# # ✅ Paso 1: Planteamiento del problema de ingeniería (sencillo)
#
# Trabajemos con un problema básico aplicado a **Ingeniería Civil**:
#
# > Calcular el **volumen de concreto** necesario para una zapata rectangular.
#
# En ingeniería, el volumen es:
#
# [
# V = largo \times ancho \times altura
# ]
#
# ---
#
# # ✅ Paso 2: Definir Entradas, Proceso y Salidas
#
# Este es el corazón del pensamiento algorítmico.
#
# ## 🔹 1. Entradas (Datos que el usuario debe proporcionar)
#
# * Largo de la zapata (m)
# * Ancho de la zapata (m)
# * Altura de la zapata (m)
#
# ## 🔹 2. Proceso (Cálculo que realiza el algoritmo)
#
# * Multiplicar largo × ancho × altura
#
# ## 🔹 3. Salida (Resultado que muestra el programa)
#
# * Volumen de concreto en metros cúbicos (m³)
#
# ---
#
# # ✅ Paso 3: Diseño del Algoritmo (en palabras)
#
# 1. Pedir al usuario el largo.
# 2. Pedir el ancho.
# 3. Pedir la altura.
# 4. Calcular el volumen multiplicando los tres valores.
# 5. Mostrar el resultado.
#
# ---
#
# # ✅ Paso 4: Pseudocódigo
#
# ```
# INICIO
#
#     Leer largo
#     Leer ancho
#     Leer altura
#
#     volumen ← largo * ancho * altura
#
#     Mostrar volumen
#
# FIN
# ```
#
# Observa que aquí estamos definiendo claramente variables y usando el operador de multiplicación `*`.
#
# ---
#
# # ✅ Paso 5: Código en Python (comentado y explicado)
#
# ```python
# # Programa para calcular el volumen de una zapata rectangular
# # Autor: Estudiante de Ingeniería
# # Descripción: Calcula el volumen de concreto en m³
#
# # Entrada de datos
# largo = float(input("Ingrese el largo de la zapata (m): "))
# ancho = float(input("Ingrese el ancho de la zapata (m): "))
# altura = float(input("Ingrese la altura de la zapata (m): "))
#
# # Proceso (cálculo)
# volumen = largo * ancho * altura
#
# # Salida
# print("\nEl volumen de concreto necesario es:", volumen, "m³")
# ```
#
# ---
#
# # ✅ Paso 6: ¿Qué estamos aprendiendo aquí?
#
# 🔹 Variables:
# `largo`, `ancho`, `altura`, `volumen`
#
# 🔹 Tipo de dato:
# `float` (números decimales)
#
# 🔹 Operadores usados:
#
# * `=` asignación
# * `*` multiplicación
#
# 🔹 Funciones usadas:
#
# * `input()`
# * `float()`
# * `print()`
#
# ---
#
# # 🎯 Reflexión Ingenieril
#
# En un proyecto real, este cálculo permite:
#
# * Estimar cantidad de concreto.
# * Calcular costos.
# * Planificar transporte y mezclado.
#
# Esto cumple con el criterio de **Aplicación en Contexto de Ingeniería** descrito en la rúbrica general .

# %% [markdown]
# ### ¿Qué es Python?
#
# Desde la perspectiva de la ingeniería, imagina a **Python** como una "navaja suiza" digital. Es un lenguaje de programación de **alto nivel**, lo que significa que su sintaxis es muy cercana al lenguaje humano (en inglés), facilitando que te concentres en la lógica del problema (el *qué*) más que en la complejidad de la máquina (el *cómo*).
#
# Para un Ingeniero Agrícola, Civil o Agroindustrial, Python es la herramienta estándar para:
#
# * **Automatizar cálculos** repetitivos (ej. diseño de vigas o canales).
# * **Analizar grandes volúmenes de datos** de sensores de humedad o estaciones meteorológicas.
# * **Crear aplicaciones interactivas** con Streamlit para mostrar resultados a clientes o supervisores.
#
# ---
#
# ### Un ejemplo de código: El enfoque de ingeniería
#
# Antes de escribir código, siempre debemos pensar en las **entradas, el proceso y las salidas**. Digamos que queremos calcular el volumen de agua necesario para llenar un tanque de almacenamiento cilíndrico en una finca.
#
# En lugar de darte el código directamente, analicemos la lógica. Para calcular el volumen ($V = \pi \cdot r^2 \cdot h$), necesitaríamos:
#
# 1. Definir el valor de $\pi$.
# 2. Pedir el radio y la altura.
# 3. Realizar la operación.
#
# Aquí tienes cómo se vería un script básico siguiendo **buenas prácticas** (variables descriptivas y modularización):

# %%
import math

def calcular_volumen_tanque(radio_m, altura_m):
    """
    Calcula el volumen de un tanque cilíndrico en metros cúbicos.
    """
    volumen = math.pi * (radio_m ** 2) * altura_m
    return volumen

# Datos de entrada con nombres descriptivos
radio_input = 2.5  # metros
altura_input = 4.0 # metros

# Llamada a la función
volumen_final = calcular_volumen_tanque(radio_input, altura_input)

print(f"El volumen del tanque es: {volumen_final:.2f} m3")

# %% [markdown]
# ---
#
# ### Tu turno: ¡A pensar como ingeniero!
#
# Para verificar que vamos por buen camino con el pensamiento algorítmico, planteemos un reto sencillo:
#
# Si tuvieras que crear un programa para calcular el **caudal ($Q$)** que pasa por una tubería, sabiendo que la fórmula es $Q = V \cdot A$ (Velocidad por Área):
#
# 1. ¿Qué nombres descriptivos le pondrías a las variables de entrada?
# 2. ¿Qué pasos lógicos (pseudocódigo) seguirías si el usuario solo te da el **diámetro** de la tubería y no el área directamente?
#
# **¿Te animas a escribirme esa lógica antes de que pasemos al código en Google Colab?**
